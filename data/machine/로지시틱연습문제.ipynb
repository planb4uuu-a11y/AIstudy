# %% [markdown]
# fish.csv데이터를 로드하여 fish_input과 fish_target으로 나뉘어 담고
# 훈련과 테스트 세트로 분리한 후 표준화 한다.
# 로지스틱 회구로 다중분류 수행한다.
# C값을 0.1, 1, 10 으로 바꿔 정확도를 비교하시오
# 결과

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

#데이터 로드

fish=pd.read_csv('./data/fish.csv')
fish
# Out:
#     Species  Weight  Length  Diagonal   Height   Width
# 0     Bream   242.0    25.4      30.0  11.5200  4.0200
# 1     Bream   290.0    26.3      31.2  12.4800  4.3056
# 2     Bream   340.0    26.5      31.1  12.3778  4.6961
# 3     Bream   363.0    29.0      33.5  12.7300  4.4555
# 4     Bream   430.0    29.0      34.0  12.4440  5.1340
# ..      ...     ...     ...       ...      ...     ...
# 154   Smelt    12.2    12.2      13.4   2.0904  1.3936
# 155   Smelt    13.4    12.4      13.5   2.4300  1.2690
# 156   Smelt    12.2    13.0      13.8   2.2770  1.2558
# 157   Smelt    19.7    14.3      15.2   2.8728  2.0672
# 158   Smelt    19.9    15.0      16.2   2.9322  1.8792
#
# [159 rows x 6 columns]

# %%
pd.unique(fish['Species'])
# Out:
# <StringArray>
# ['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt']
# Length: 7, dtype: str

# %%
fish_input=fish[['Weight','Length','Diagonal','Height','Width']].to_numpy()
fish_target=fish[['Species']].to_numpy()

# %%
#훈련세트만들기
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target=train_test_split(fish_input,fish_target)

# %%
#표준화
from sklearn.preprocessing import StandardScaler
ss=StandardScaler() 
ss.fit(train_input) 
train_scaled=ss.transform(train_input) 
test_scaled=ss.transform(test_input)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(C=10, max_iter=1000)
lr.fit(train_scaled,train_target)
# Out:
# LogisticRegression(C=10, max_iter=1000)

# %%
lr.score(train_scaled,train_target)
# Out:
# 0.9327731092436975

# %%
lr.score(test_scaled,test_target)
# Out:
# 0.825

# %% [markdown]
# # 문제2 이진 분류

# %%
train_target = train_target.reshape(-1)
bream_smelt_indexes = (train_target == 'Bream') | (train_target == 'Smelt')
train_bream_smelt = train_scaled[bream_smelt_indexes]
target_bream_smelt = train_target[bream_smelt_indexes]

print(train_bream_smelt)
print(target_bream_smelt)
# Out:
# [[ 0.84406293  0.57515463  0.80488106  1.6757329   0.91398021]
#  [ 0.4228291   0.47514966  0.67578393  1.38137412  0.60824455]
#  [ 0.0718009   0.07512978  0.27005011  1.11280609  0.14954624]
#  [ 0.52111699  0.42514718  0.59279292  1.50196202  0.33284858]
#  [ 0.0718009   0.04512829  0.23316522  1.01659869  0.20238788]
#  [ 0.49303474  0.27513972  0.4636958   1.45535223  0.61488135]
#  [-1.15427039 -1.68495768 -1.72173411 -1.65387962 -2.11000275]
#  [ 0.21221218  0.17513475  0.37148357  1.2004086   0.13108959]
#  [ 0.21221218  0.14513326  0.37148357  1.16579784  0.22261435]
#  [-1.15764026 -1.6249547  -1.69407044 -1.69045038 -2.11834617]
#  [-1.16381835 -1.74496066 -1.75861901 -1.70553283 -2.10064801]
#  [-0.37751519 -0.2948886  -0.0895776   0.74831749 -0.19063762]
#  [-0.23710391 -0.27488761 -0.09879882  0.72388918  0.05618846]
#  [ 0.77385729  0.37514469  0.5835717   1.33583993  0.37311189]
#  [ 0.73173391  0.47514966  0.64812026  1.58815429  0.48239801]
#  [ 0.77385729  0.37514469  0.56512925  1.31729162  0.42867146]
#  [ 0.71769278  0.57515463  0.77721739  1.46266638  0.96290297]
#  [-0.09669263  0.07512978  0.26082889  0.79373216  0.05233279]
#  [ 0.83002181  0.57515463  0.77721739  1.67616314  0.93724064]
#  [ 1.48995482  0.92517203  1.09073898  2.08781129  1.0649202 ]
#  [-1.16438    -1.72495967 -1.74939778 -1.70780357 -2.18623124]
#  [ 1.19509113  0.6751596   0.86942962  1.80232032  1.00575779]
#  [ 0.21221218  0.22513724  0.38992601  1.05407775 -0.15119601]
#  [ 0.81317245  0.6751596   0.8602084   1.71325976  0.78649027]
#  [ 1.61632497  0.77516457  0.96164185  2.29647975  1.26149616]
#  [ 1.40570805  1.025177    1.21061488  2.24800557  1.35422186]
#  [-1.17083892 -1.87496712 -1.89693735 -1.76335288 -2.17889915]
#  [ 1.39166692  0.92517203  1.0999602   2.07655323  1.07395891]
#  [ 0.63344602  0.42514718  0.60201415  1.22488472  0.70817592]
#  [-0.51231002 -0.38489308 -0.20023228  0.51885389 -0.37115882]
#  [ 0.49303474  0.27513972  0.4636958   1.33975993  0.35623543]
#  [ 0.01563639 -0.02487519  0.16861665  0.73971261  0.332975  ]
#  [-1.17224303 -1.86496663 -1.89693735 -1.82157927 -2.18623124]
#  [ 1.47591369  1.17518445  1.32126956  1.97774046  1.11453825]
#  [ 0.14200654  0.17513475  0.37148357  1.17445053  0.3141391 ]]
# ['Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Smelt' 'Bream' 'Bream'
#  'Smelt' 'Smelt' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream'
#  'Bream' 'Bream' 'Smelt' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Smelt'
#  'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Smelt' 'Bream' 'Bream']

# %%
train_bream_smelt[0,]
# Out:
# array([0.84406293, 0.57515463, 0.80488106, 1.6757329 , 0.91398021])

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(train_bream_smelt,target_bream_smelt)
# Out:
# LogisticRegression()

# %%
lr.predict(train_bream_smelt[:5])
# Out:
# array(['Bream', 'Bream', 'Bream', 'Bream', 'Bream'], dtype=object)

# %%
lr.predict_proba(train_bream_smelt[:5])
# Out:
# array([[0.99793423, 0.00206577],
#        [0.99548754, 0.00451246],
#        [0.98521489, 0.01478511],
#        [0.99480218, 0.00519782],
#        [0.98389615, 0.01610385]])

# %%
lr.classes_
# Out:
# array(['Bream', 'Smelt'], dtype=object)

# %%
train_bream_smelt[0,]
# Out:
# array([0.84406293, 0.57515463, 0.80488106, 1.6757329 , 0.91398021])

# %%
decisions=lr.decision_function(train_bream_smelt[:5])
decisions
# Out:
# array([-6.18018227, -5.39639044, -4.19923931, -5.25430409, -4.11246206])

# %%
from scipy.special import expit #시그모이드 함수 파이선에서 제공해주는것. 확률값을 알려줌. 
expit(decisions)
# Out:
# array([0.00206577, 0.00451246, 0.01478511, 0.00519782, 0.01610385])

# %%
lr.predict_proba(train_bream_smelt[:5])
# Out:
# array([[0.99793423, 0.00206577],
#        [0.99548754, 0.00451246],
#        [0.98521489, 0.01478511],
#        [0.99480218, 0.00519782],
#        [0.98389615, 0.01610385]])

# %%
lr.coef_,lr.intercept_
# Out:
# (array([[-0.37528434, -0.56992951, -0.64545664, -0.88224157, -0.73819139]]),
#  array([-2.8630117]))
