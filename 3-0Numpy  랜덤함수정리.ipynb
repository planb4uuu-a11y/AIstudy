# %%
import numpy as np

# %%
np.random.rand()
# Out:
# 0.17031626064329397

# %%
np.random.rand(5)
# Out:
# array([0.95776299, 0.44171027, 0.42802416, 0.02154642, 0.75975117])

# %%
np.random.rand(2,3)
# Out:
# array([[0.11367297, 0.99842539, 0.27781419],
#        [0.02817253, 0.09403523, 0.09157082]])

# %%
np.random.random(5)
# Out:
# array([0.33176828, 0.12193628, 0.94201603, 0.94122815, 0.88992453])

# %%
#정수난수발생
np.random.randint(1,10)
# Out:
# 9

# %%
np.random.randint(1,10,5)
# Out:
# array([5, 5, 5, 1, 5], dtype=int32)

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(0, 1, 1000)

plt.hist(data, bins=30)
plt.show()

# %%
np.random.uniform()
#균등분포 (min-max사이 동일 확률)
# Out:
# 0.417558002003416

# %%
np.random.uniform(0,10,5)
# Out:
# array([3.3007649 , 1.90756103, 8.51026231, 4.77014041, 1.01102391])

# %%
#choice는 리스테에서 선택
np.random.choice([10,20,40])
# Out:
# np.int64(10)

# %%
np.random.choice([10,20,30],size=5)
#중복허용하면서 5개반 뽑음
# Out:
# array([10, 10, 30, 30, 20])

# %%
#중복없이
np.random.choice([10,20,30,40],size=2, replace=False)
# Out:
# array([10, 30])

# %%
#난수의 시작점. 난수의 시작점 번호에 난수가 정해져 있음
np.random.seed(0)
np.random.random(2)
# Out:
# array([0.5488135 , 0.71518937])

# %%
np.random.seed(0)
np.random.random(5)
# Out:
# array([0.5488135 , 0.71518937, 0.60276338, 0.54488318, 0.4236548 ])

# %%
np.random.seed(0)
np.random.random(7)
# Out:
# array([0.5488135 , 0.71518937, 0.60276338, 0.54488318, 0.4236548 ,
#        0.64589411, 0.43758721])

# %%
np.random.seed(42)
np.random.random(7)
# Out:
# array([0.37454012, 0.95071431, 0.73199394, 0.59865848, 0.15601864,
#        0.15599452, 0.05808361])

# %%
np.random.seed(42)
np.random.random(10)
# Out:
# array([0.37454012, 0.95071431, 0.73199394, 0.59865848, 0.15601864,
#        0.15599452, 0.05808361, 0.86617615, 0.60111501, 0.70807258])

# %%
plt
plt.subplot(1,2,1)
plt.hist(np.random.normal(0,1,1000))
plt.title("normal")
plt.show()

plt.subplot(1,2,2)
plt.hist(np.random.normal(0,1,1000))
plt.title("normal")
plt.show()
